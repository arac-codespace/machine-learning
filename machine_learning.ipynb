# %%
from data_load.well_data_load import Station  
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
id = "175711066143600"
start = datetime(1950, 1, 1).replace(microsecond=0)
end = datetime.now().replace(microsecond=0)
source= "USGS"
station = Station().find_data(id, start, end, source)
# Out:
# Creating engine for pr_timeseries at DESKTOP-4IL536V\SQLEXPRESS
# Loading database records...
# Creating engine for pr_timeseries at DESKTOP-4IL536V\SQLEXPRESS
# Loading database records...

# %%
df = station.get_data()
df
# Out:
#             station_id source_x           date_time timezone  water_depth  \
# 0      175711066143600     USGS 2009-10-13 20:00:00      AST         1.95
# 1      175711066143600     USGS 2009-10-13 21:00:00      AST         1.94
# 2      175711066143600     USGS 2009-10-13 23:00:00      AST         1.96
# 3      175711066143600     USGS 2009-10-14 01:00:00      AST         1.97
# 4      175711066143600     USGS 2009-10-14 03:00:00      AST         1.98
# ...                ...      ...                 ...      ...          ...
# 72743  175711066143600     USGS 2009-10-07 12:00:00      AST         2.14
# 72744  175711066143600     USGS 2015-08-20 01:00:00      AST         3.33
# 72745  175711066143600     USGS 2015-10-01 05:00:00      AST         3.94
# 72746  175711066143600     USGS 2015-05-24 19:00:00      AST         4.00
# 72747  175711066143600     USGS 2014-12-31 11:00:00      AST         3.00
#
#       data_flag source_y                          station_name   latitude  \
# 0             A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 1             A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 2             A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 3             A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 4             A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# ...         ...      ...                                   ...        ...
# 72743         A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 72744         A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 72745         A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 72746         A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
# 72747         A     USGS  PIEZOMETER JBNERR EAST 1 SALINAS, PR  17.951023
#
#        longitude  datum   county  gage_altitude vertical_datum  \
# 0     -66.242862  NAD83  Salinas            4.9         NGVD29
# 1     -66.242862  NAD83  Salinas            4.9         NGVD29
# 2     -66.242862  NAD83  Salinas            4.9         NGVD29
# 3     -66.242862  NAD83  Salinas            4.9         NGVD29
# 4     -66.242862  NAD83  Salinas            4.9         NGVD29
# ...          ...    ...      ...            ...            ...
# 72743 -66.242862  NAD83  Salinas            4.9         NGVD29
# 72744 -66.242862  NAD83  Salinas            4.9         NGVD29
# 72745 -66.242862  NAD83  Salinas            4.9         NGVD29
# 72746 -66.242862  NAD83  Salinas            4.9         NGVD29
# 72747 -66.242862  NAD83  Salinas            4.9         NGVD29
#
#       hydrologic_unit local_aquifer  well_depth
# 0            21010004       110SCPL        74.0
# 1            21010004       110SCPL        74.0
# 2            21010004       110SCPL        74.0
# 3            21010004       110SCPL        74.0
# 4            21010004       110SCPL        74.0
# ...               ...           ...         ...
# 72743        21010004       110SCPL        74.0
# 72744        21010004       110SCPL        74.0
# 72745        21010004       110SCPL        74.0
# 72746        21010004       110SCPL        74.0
# 72747        21010004       110SCPL        74.0
#
# [72748 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['station_id', 'source_x', 'date_time', 'timezone', 'water_depth',
#        'data_flag', 'source_y', 'station_name', 'latitude', 'longitude',
#        'datum', 'county', 'gage_altitude', 'vertical_datum', 'hydrologic_unit',
#        'local_aquifer', 'well_depth'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-82e16a75f7d0> in <module>
# ----> 1 from data_load.usgs_data_wrangling import get_country_name
#
# ImportError: cannot import name 'get_country_name' from 'data_load.usgs_data_wrangling' (C:\Users\alexa\Documents\scripts\machine_learning\data_load\usgs_data_wrangling.py)
