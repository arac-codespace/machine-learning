# %% [markdown]
# # Notebook for plotting data with Plotly

# %%
from data_load.usgs_data_load import USGS

usgs = USGS()
sites_df = usgs.get_sites(
    stateCd="pr",
    siteType="GW",
    parameterCd="72019", #Groundwater Depth
    siteStatus="all",
#     aquiferCd="N300STHCST",
    localAquiferCd = "PR:110SCPL",
    startDt="1990-01-01"
)

sites_df
# Out:
# Calling: https://waterservices.usgs.gov/nwis
# https://waterservices.usgs.gov/nwis/site/?stateCd=pr&siteType=GW&parameterCd=72019&siteStatus=all&localAquiferCd=PR:110SCPL&startDt=1990-01-01
#     agency_cd          site_no                                station_nm  \
# 0        USGS  175708066163000  PIEZOMETER ERMITANO CENTRAL, SALINAS, PR
# 1        USGS  175708066163001     PIEZOMETER ERMITANO NORTH SALINAS, PR
# 2        USGS  175709066163200         PIEZOMETER USGS J-18, SALINAS, PR
# 3        USGS  175711066143600      PIEZOMETER JBNERR EAST 1 SALINAS, PR
# 4        USGS  175711066143601      PIEZOMETER JBNERR EAST 2 SALINAS, PR
# ..        ...              ...                                       ...
# 104      USGS  180143066393200                      LVEL WELL, PONCE, PR
# 105      USGS  180151066220900            SEMIDEY WELL, SANTA ISABEL, PR
# 106      USGS  180202066323800                     MAR 2 WELL, PONCE, PR
# 107      USGS  180247066304000            AUTOPISTA WELL, JUANA DIAZ, PR
# 108      USGS  180426066321100               CAYABO WELL, JUANA DIAZ, PR
#
#     site_tp_cd   dec_lat_va   dec_long_va coord_acy_cd dec_coord_datum_cd  \
# 0           GW  17.95024496  -66.27433468            5              NAD83
# 1           GW  17.95013385    -66.274668            5              NAD83
# 2           GW  17.95038384  -66.27511247            S              NAD83
# 3        GW-MW   17.9510227  -66.24286198            5              NAD83
# 4        GW-MW  17.95101992   -66.2428703            5              NAD83
# ..         ...          ...           ...          ...                ...
# 104         GW  18.02649805   -66.6584567            5              NAD83
# 105         GW  18.02890823   -66.3683082            5              NAD83
# 106         GW  18.03182517   -66.5435055            5              NAD83
# 107         GW  18.04446322      -66.5107            5              NAD83
# 108         GW   18.0720596  -66.53601679            5              NAD83
#
#       alt_va alt_acy_va alt_datum_cd    huc_cd
# 0       1.66        1.6       NGVD29  21010004
# 1       1.18        1.6       NGVD29  21010005
# 2       1.21        1.6       NGVD29  21010004
# 3        4.9        1.6       NGVD29  21010004
# 4        4.9        1.6       NGVD29  21010004
# ..       ...        ...          ...       ...
# 104   109.49         15       NGVD29  21010004
# 105    230.0          5       NGVD29  21010004
# 106   126.28        1.6       NGVD29  21010004
# 107   130.86        14.       NGVD29  21010004
# 108   319.21         32       NGVD29  21010004
#
# [109 rows x 12 columns]

# %%
from arcgis.gis import GIS
my_gis = GIS()
m = my_gis.map()
m
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-0d8b37b6-aff3-4c66-8d9e-167232870dc7"><img src=""></img></div>

# %%
import ipywidgets as widgets
from ipywidgets import interact
def f(x):
    return x
interact(f, x=10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.f(x)>
